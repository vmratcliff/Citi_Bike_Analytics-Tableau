# %%
import os
import glob
import pandas as pd
os.chdir("bike_data")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv("combined_csv.csv", index=True, encoding='utf-8-sig')

# %%
# The path to our CSV file
file = "../bike_data/combined_csv.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# print(len(df))
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0           142  2019-02-01 15:35:02.0820
# 1           1           223  2019-02-01 17:00:46.8900
# 2           2           106  2019-02-01 17:08:01.3260
# 3           3           370  2019-02-01 17:09:31.2100
# 4           4           315  2019-02-01 17:19:53.2490
#
#                    stoptime  start station id start station name  \
# 0  2019-02-01 15:37:24.1360              3183     Exchange Place
# 1  2019-02-01 17:04:30.5500              3183     Exchange Place
# 2  2019-02-01 17:09:47.4400              3183     Exchange Place
# 3  2019-02-01 17:15:41.6550              3183     Exchange Place
# 4  2019-02-01 17:25:09.1400              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3639
# 1               40.716247               -74.033459            3681
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3211
# 4               40.716247               -74.033459            3273
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0       Harborside             40.719252             -74.034234   29677
# 1         Grand St             40.715178             -74.037683   26234
# 2      Paulus Hook             40.714145             -74.033552   29588
# 3       Newark Ave             40.721525             -74.046305   29250
# 4     Manila & 1st             40.721651             -74.042884   29586
#
#      usertype  birth year  gender
# 0  Subscriber        1963       1
# 1  Subscriber        1992       2
# 2  Subscriber        1960       1
# 3  Subscriber        1976       1
# 4  Subscriber        1980       1
